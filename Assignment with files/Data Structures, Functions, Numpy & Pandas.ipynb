# %%
#1
# Question 1: List Operations

# Create a list of 5 integers
numbers = [5, 2, 8, 1, 5]

print("Original list:", numbers)

# append()
numbers.append(10)
print("After append:", numbers)

# extend()
numbers.extend([3, 7])
print("After extend:", numbers)

# insert()
numbers.insert(2, 20)
print("After insert:", numbers)

# remove()
numbers.remove(5)
print("After remove:", numbers)

# pop()
removed_value = numbers.pop()
print("Popped value:", removed_value)
print("After pop:", numbers)

# index()
print("Index of 8:", numbers.index(8))

# count()
print("Count of 5:", numbers.count(5))

# sort()
numbers.sort()
print("After sort:", numbers)

# reverse()
numbers.reverse()
print("After reverse:", numbers)

# clear()
numbers.clear()
print("After clear:", numbers)
# Out:
# Original list: [5, 2, 8, 1, 5]
# After append: [5, 2, 8, 1, 5, 10]
# After extend: [5, 2, 8, 1, 5, 10, 3, 7]
# After insert: [5, 2, 20, 8, 1, 5, 10, 3, 7]
# After remove: [2, 20, 8, 1, 5, 10, 3, 7]
# Popped value: 7
# After pop: [2, 20, 8, 1, 5, 10, 3]
# Index of 8: 2
# Count of 5: 1
# After sort: [1, 2, 3, 5, 8, 10, 20]
# After reverse: [20, 10, 8, 5, 3, 2, 1]
# After clear: []
